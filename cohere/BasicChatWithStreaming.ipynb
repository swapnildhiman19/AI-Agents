# %% [markdown]
# #Chat with streaming feature from Cohere means :  Words/tokens come in real time, just like ChatGPT’s “typing” effect. Useful for responsive UIs. This comes as an event from a stream and not as single response, great for conversational chatbot use case.

# %%
import os
from dotenv import load_dotenv

load_dotenv()
COHERE_API_KEY = os.getenv("COHERE_API_KEY")

import cohere
co = cohere.Client(api_key=COHERE_API_KEY)

# %%
import cohere  # Install if needed: pip install cohere

# Initialize client
co = cohere.ClientV2(api_key=COHERE_API_KEY)

# Simplified messages for testing (fresh start to avoid history issues)
# Comment this out and uncomment your full messages below if you want to test with history
messages = [
    {
        "role": "system",
        "content": "You are an AI expert."
    },
    {
        "role": "user",
        "content": [
            {
                "type": "text",
                "text": "What skills should I learn to stay relevant as an iOS developer?"
            }
        ]
    }
]

# Your original full messages (uncomment to use, but test simplified first)
# messages = [
#     {
#         "role": "system",
#         "content": "You have whole knowledge of AI, it's impact in various industries and have all the information about how specific tech companies are integrating it and where exactly they are cutting the roles because of that."
#     },
#     {
#         "role": "user",
#         "content": [
#             {
#                 "type": "text",
#                 "text": "Whether AI will replace a human who is working as an iOS Software Developer III role in Walmart for post purchase International market. If yes, then how long it will take to replace the human with AI? If no, then why not?. Need a honest answer."
#             }
#         ]
#     },
#     {
#         "role": "assistant",
#         "content": "The question of whether AI will replace a human in an **iOS Software Developer III role at Walmart for the post-purchase international market** is nuanced and depends on several factors. Here’s an honest assessment:\n\n### **Will AI Replace the Role?**\n**No, AI will not fully replace the role in the foreseeable future**, but it will significantly augment and transform parts of the job. Here’s why:\n\n1. **Complexity of iOS Development**:\n   - iOS development involves creative problem-solving, architectural decisions, and understanding complex business requirements. While AI tools (like GitHub Copilot, ChatGPT, or AI-driven code generators) can assist with writing code, debugging, or suggesting optimizations, they cannot yet handle the full scope of a senior developer’s responsibilities.\n   - Tasks like designing system architectures, making trade-offs between technical solutions, or aligning development with business goals require human judgment and experience.\n\n2. **Domain-Specific Knowledge**:\n   - The role involves working in the **post-purchase international market**, which requires understanding Walmart’s specific systems, processes, and international customer needs. AI lacks this domain-specific knowledge and contextual understanding.\n\n3. **Creativity and Innovation**:\n   - Senior developers often innovate, experiment with new technologies, and adapt to evolving industry trends. AI is not yet capable of driving innovation independently; it relies on human guidance.\n\n4. **Collaboration and Communication**:\n   - The role involves collaborating with cross-functional teams, stakeholders, and international markets. AI cannot replace human communication skills, empathy, and the ability to navigate complex organizational dynamics.\n\n### **How AI Will Impact the Role**\nWhile AI won’t replace the role entirely, it will **transform how the job is done**:\n   - **Automation of Repetitive Tasks**: AI tools will handle repetitive coding tasks, testing, and bug fixing, allowing developers to focus on higher-value work.\n   - **Enhanced Productivity**: AI-driven tools will speed up development cycles and improve code quality.\n   - **Skill Shift**: Developers will need to upskill in areas like AI integration, machine learning, and managing AI-driven tools.\n\n### **Timeline for AI Integration**\n- **Short Term (1–3 years)**: AI tools will become more integrated into the development workflow, automating mundane tasks and improving productivity.\n- **Medium Term (3–7 years)**: AI will play a larger role in code generation, testing, and optimization, but human oversight and decision-making will remain critical.\n- **Long Term (7+ years)**: AI may handle more complex tasks, but the need for human creativity, strategic thinking, and domain expertise will persist.\n\n### **Conclusion**\nAI will not replace an **iOS Software Developer III** at Walmart in the foreseeable future. Instead, it will augment the role, making developers more efficient and enabling them to focus on higher-value tasks. However, developers will need to adapt and acquire new skills to work effectively alongside AI tools. The role will evolve, but it will remain fundamentally human-driven."
#     },
#     {
#         "role": "user",
#         "content": [
#             {
#                 "type": "text",
#                 "text": "What skills should I learn to stay relevant?"
#             }
#         ]
#     }
# ]

# Call chat_stream
try:
    stream = co.chat_stream(
        model="command-r-plus",  # Valid model; change if needed
        messages=messages,
        temperature=0.3
    )

    # Handle the stream with debugging
    full_response = ""  # To collect the full text
    for event in stream:
        print(f"\n[DEBUG] Event type: {event.type}")  # Debug: Show every event type
        print(f"[DEBUG] Event details: {event}")     # Debug: Show full event content

        if event.type == "content-delta":
            if hasattr(event.delta, 'text') and event.delta.text:  # Check for text and if it's not empty
                print(event.delta.text, end='', flush=True)  # Print in real-time
                full_response += event.delta.text
        elif event.type == "message-end":
            print("\n\nStreaming complete!")
            print("Full response:", full_response)

except Exception as e:
    print(f"API Error: {e}")  # Catch and print any API issues
# Out:
# [DEBUG] Event type: message-start
# [DEBUG] Event details: type='message-start' id='5f199d11-1f25-44b5-a1f5-d1ffe503c0cf' delta=ChatMessageStartEventDelta(message=ChatMessageStartEventDeltaMessage(role='assistant', content=[], tool_plan='', tool_calls=[], citations=[]))
#
# [DEBUG] Event type: content-start
# [DEBUG] Event details: type='content-start' index=0 delta=ChatContentStartEventDelta(message=ChatContentStartEventDeltaMessage(content=ChatContentStartEventDeltaMessageContent(text='', type='text')))
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text='As'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' an'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' iOS'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' developer'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=','))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' there'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' are'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' several'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' skills'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' that'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' you'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' can'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' learn'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' to'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' stay'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' relevant'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' and'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' competitive'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' in'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' the'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' job'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' market'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text='.'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' Here'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' are'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' some'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' key'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' skills'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' that'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' may'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' be'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' valuable'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' for'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' you'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' to'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' acquire'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' or'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' improve'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' upon'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=':'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text='\n\n-'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' Swift'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' Programming'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' Language'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=':'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' Apple'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text="'s"))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' Swift'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' programming'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' language'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' is'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' specifically'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' designed'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' for'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' iOS'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=','))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' macOS'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=','))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' watch'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text='OS'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=','))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' and'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' tv'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text='OS'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text='.'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' Having'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' a'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' strong'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' understanding'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' of'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' Swift'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' is'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' essential'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' for'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' any'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' iOS'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' developer'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text='.'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' Stay'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' up'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' to'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' date'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' with'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' the'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' latest'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' versions'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' and'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' updates'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' to'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' the'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' language'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=','))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' and'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' practice'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' writing'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' clean'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=','))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' efficient'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=','))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' and'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' readable'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' code'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text='.'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text='\n\n-'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' User'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' Interface'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' Design'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=':'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' Creating'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' visually'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' appealing'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' and'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' user'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text='-'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text='friendly'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' interfaces'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' is'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' crucial'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' for'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' the'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' success'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' of'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' any'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' iOS'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' application'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text='.'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' Learn'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' about'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' design'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' principles'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=','))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' user'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' experience'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' ('))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text='UX'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=')'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' best'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' practices'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=','))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' and'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' how'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' to'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' use'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' tools'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' like'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' Sketch'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' or'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' Adobe'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' XD'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' to'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' create'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' mock'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text='ups'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' and'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' prototypes'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text='.'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text='\n\n-'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' Architecture'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' Patterns'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=':'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' Familiar'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text='ize'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' yourself'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' with'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' popular'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' architecture'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' patterns'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' used'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' in'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' iOS'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' development'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=','))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' such'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' as'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' Model'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text='-'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text='View'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text='-'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text='Controller'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' ('))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text='MVC'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text='),'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' Model'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text='-'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text='View'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text='-'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text='ViewModel'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' ('))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text='MV'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text='VM'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text='),'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' or'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' Model'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text='-'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text='View'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text='-'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# ...
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' Stay'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' active'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' in'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' the'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' iOS'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' development'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' community'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=','))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' participate'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' in'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' forums'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=','))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' attend'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' conferences'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=','))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' and'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' join'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' developer'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' groups'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' to'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' stay'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' informed'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' about'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' the'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' latest'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' trends'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' and'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' best'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' practices'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text='.'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text='\n\nBy'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' investing'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' time'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' and'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' effort'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' in'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' acquiring'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' and'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' improving'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' these'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' skills'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=','))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' you'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' can'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' enhance'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' your'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' value'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' as'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' an'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' iOS'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' developer'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' and'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' stay'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' relevant'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' in'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' the'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' ever'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text='-'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text='changing'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' landscape'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' of'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' mobile'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text=' development'))) logprobs=None
#
# [DEBUG] Event type: content-delta
# [DEBUG] Event details: type='content-delta' index=0 delta=ChatContentDeltaEventDelta(message=ChatContentDeltaEventDeltaMessage(content=ChatContentDeltaEventDeltaMessageContent(text='.'))) logprobs=None
#
# [DEBUG] Event type: content-end
# [DEBUG] Event details: type='content-end' index=0
#
# [DEBUG] Event type: message-end
# [DEBUG] Event details: type='message-end' id=None delta=ChatMessageEndEventDelta(error=None, finish_reason='COMPLETE', usage={'billed_units': {'input_tokens': 19, 'output_tokens': 696}, 'tokens': {'input_tokens': 28, 'output_tokens': 696}})
#
#
# Streaming complete!
# Full response:
